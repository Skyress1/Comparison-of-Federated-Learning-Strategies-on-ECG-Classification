# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q flwr["simulation"] tensorflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 MB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 68.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 52.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 5.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 98.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 36.9 MB/s eta 0:00:00
#   Building wheel for gpustat (pyproject.toml) ... done

# %%
import flwr as fl
import tensorflow as tf
import numpy as np
from typing import List, Tuple
from flwr.common import Metrics
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
client_0_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_X_train.npy")
client_0_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_y_train.npy")
client_0_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_X_test.npy")
client_0_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_y_test.npy")

client_1_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_X_train.npy")
client_1_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_y_train.npy")
client_1_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_X_test.npy")
client_1_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_y_test.npy")

client_2_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_X_train.npy")
client_2_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_y_train.npy")
client_2_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_X_test.npy")
client_2_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_y_test.npy")

client_3_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_X_train.npy")
client_3_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_y_train.npy")
client_3_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_X_test.npy")
client_3_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_y_test.npy")

client_4_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_X_train.npy")
client_4_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_y_train.npy")
client_4_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_X_test.npy")
client_4_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_y_test.npy")

client_5_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_X_train.npy")
client_5_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_y_train.npy")
client_5_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_X_test.npy")
client_5_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_y_test.npy")

# %%
x_train = [client_0_train_data, client_1_train_data, client_2_train_data, client_3_train_data, client_4_train_data, client_5_train_data]
y_train = [client_0_train_label, client_1_train_label, client_2_train_label, client_3_train_label, client_4_train_label, client_5_train_label]
x_test = [client_0_test_data, client_1_test_data, client_2_test_data, client_3_test_data, client_4_test_data, client_5_test_data]
y_test = [client_0_test_label, client_1_test_label, client_2_test_label, client_3_test_label, client_4_test_label, client_5_test_label]

# %%
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, model, x_train_cid, y_train_cid, x_test_cid, y_test_cid) -> None:
        self.model = model
        self.x_train_cid, self.y_train_cid = x_train_cid, y_train_cid
        self.x_test_cid, self.y_test_cid = x_test_cid, y_test_cid

    def get_parameters(self, config):
        return self.model.get_weights()

    def fit(self, parameters, config):
        self.model.set_weights(parameters)
        self.model.fit(self.x_train_cid, self.y_train_cid, epochs=5, batch_size=32, verbose=0)
        return self.model.get_weights(), len(self.x_train_cid), {}

    def evaluate(self, parameters, config):
        self.model.set_weights(parameters)
        loss, acc = self.model.evaluate(self.x_test_cid, self.y_test_cid, verbose=0)
        return loss, len(self.x_test_cid), {"accuracy": acc}

# %%
def client_fn(cid: str) -> fl.client.Client:

    model = Sequential([
      layers.Conv1D(16, 3, padding='same', activation='relu', input_shape=(180,1)),
      layers.MaxPool1D(),
      layers.Conv1D(32, 3, padding='same', activation='relu'),
      layers.MaxPool1D(),
      layers.Conv1D(64, 3, padding='same', activation='relu'),
      layers.MaxPool1D(),
      layers.Flatten(),
      layers.Dense(256, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(5 ,activation="softmax")
    ])
    model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=[tf.keras.metrics.CategoricalAccuracy()])

    x_train_cid = x_train[int(cid)]
    y_train_cid = y_train[int(cid)]

    x_test_cid = x_test[int(cid)]
    y_test_cid = y_test[int(cid)]


    return FlowerClient(model, x_train_cid, y_train_cid, x_test_cid, y_test_cid)

# %%
def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:

    print(metrics)
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]


    return {"accuracy": sum(accuracies) / sum(examples)}

# %%
#created for initial parameters
model = Sequential([
  layers.Conv1D(16, 3, padding='same', activation='relu', input_shape=(180,1)),
  layers.MaxPool1D(),
  layers.Conv1D(32, 3, padding='same', activation='relu'),
  layers.MaxPool1D(),
  layers.Conv1D(64, 3, padding='same', activation='relu'),
  layers.MaxPool1D(),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(64, activation='relu'),
  layers.Dense(5 ,activation="softmax")
])

# %%
strategy = fl.server.strategy.FedYogi(
    fraction_fit=1.0,
    fraction_evaluate=0.5,
    min_fit_clients=6,
    min_evaluate_clients=3,
    min_available_clients=6,
    initial_parameters=fl.common.ndarrays_to_parameters(model.get_weights()),
    evaluate_metrics_aggregation_fn=weighted_average,
)

client_resources = None


fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=6,
    config=fl.server.ServerConfig(num_rounds=10),
    strategy=strategy,
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-06-17 19:14:51,146 | app.py:146 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# 2023-06-17 19:14:56,148	INFO worker.py:1636 -- Started a local Ray instance.
# INFO flwr 2023-06-17 19:14:58,770 | app.py:180 | Flower VCE: Ray initialized with resources: {'node:172.28.0.12': 1.0, 'CPU': 2.0, 'object_store_memory': 3890064998.0, 'memory': 7780129998.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'node:172.28.0.12': 1.0, 'CPU': 2.0, 'object_store_memory': 3890064998.0, 'memory': 7780129998.0}
# INFO flwr 2023-06-17 19:14:58,780 | server.py:86 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2023-06-17 19:14:58,787 | server.py:269 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2023-06-17 19:14:58,802 | server.py:88 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2023-06-17 19:14:58,815 | server.py:101 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2023-06-17 19:14:58,818 | server.py:218 | fit_round 1: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 1: strategy sampled 6 clients (out of 6)
# (pid=1363) 2023-06-17 19:15:02.912929: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG flwr 2023-06-17 19:18:58,444 | server.py:232 | fit_round 1 received 6 results and 0 failures
# DEBUG:flwr:fit_round 1 received 6 results and 0 failures
# WARNING flwr 2023-06-17 19:18:58,503 | fedavg.py:243 | No fit_metrics_aggregation_fn provided
# WARNING:flwr:No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-06-17 19:18:58,555 | server.py:168 | evaluate_round 1: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 1: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 19:19:04,563 | server.py:182 | evaluate_round 1 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 1 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 19:19:04,566 | server.py:218 | fit_round 2: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 2: strategy sampled 6 clients (out of 6)
# [(6060, {'accuracy': 0.8384488224983215}), (5098, {'accuracy': 0.9848960638046265}), (5211, {'accuracy': 0.6102475523948669})]
# DEBUG flwr 2023-06-17 19:22:54,853 | server.py:232 | fit_round 2 received 6 results and 0 failures
# DEBUG:flwr:fit_round 2 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 19:22:54,930 | server.py:168 | evaluate_round 2: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 2: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 19:22:58,295 | server.py:182 | evaluate_round 2 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 2 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 19:22:58,299 | server.py:218 | fit_round 3: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 3: strategy sampled 6 clients (out of 6)
# [(4762, {'accuracy': 0.9086518287658691}), (5211, {'accuracy': 0.6104394793510437}), (6060, {'accuracy': 0.8391088843345642})]
# DEBUG flwr 2023-06-17 19:26:50,014 | server.py:232 | fit_round 3 received 6 results and 0 failures
# DEBUG:flwr:fit_round 3 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 19:26:50,085 | server.py:168 | evaluate_round 3: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 3: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 19:26:53,555 | server.py:182 | evaluate_round 3 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 3 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 19:26:53,562 | server.py:218 | fit_round 4: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 4: strategy sampled 6 clients (out of 6)
# [(5211, {'accuracy': 0.6158127188682556}), (5573, {'accuracy': 0.7638614773750305}), (6138, {'accuracy': 0.7606712579727173})]
# DEBUG flwr 2023-06-17 19:30:45,850 | server.py:232 | fit_round 4 received 6 results and 0 failures
# DEBUG:flwr:fit_round 4 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 19:30:45,927 | server.py:168 | evaluate_round 4: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 4: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 19:30:51,967 | server.py:182 | evaluate_round 4 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 4 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 19:30:51,972 | server.py:218 | fit_round 5: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 5: strategy sampled 6 clients (out of 6)
# [(6060, {'accuracy': 0.8602310419082642}), (6138, {'accuracy': 0.7673509120941162}), (4762, {'accuracy': 0.9216715693473816})]
# DEBUG flwr 2023-06-17 19:34:41,549 | server.py:232 | fit_round 5 received 6 results and 0 failures
# DEBUG:flwr:fit_round 5 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 19:34:41,618 | server.py:168 | evaluate_round 5: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 5: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 19:34:45,951 | server.py:182 | evaluate_round 5 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 5 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 19:34:45,957 | server.py:218 | fit_round 6: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 6: strategy sampled 6 clients (out of 6)
# [(6138, {'accuracy': 0.7046269178390503}), (5211, {'accuracy': 0.619266927242279}), (5098, {'accuracy': 0.7524519562721252})]
# DEBUG flwr 2023-06-17 19:38:34,976 | server.py:232 | fit_round 6 received 6 results and 0 failures
# DEBUG:flwr:fit_round 6 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 19:38:35,037 | server.py:168 | evaluate_round 6: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 6: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 19:38:38,342 | server.py:182 | evaluate_round 6 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 6 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 19:38:38,345 | server.py:218 | fit_round 7: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 7: strategy sampled 6 clients (out of 6)
# [(6138, {'accuracy': 0.6914304494857788}), (5098, {'accuracy': 0.5574735403060913}), (5211, {'accuracy': 0.6966033577919006})]
# DEBUG flwr 2023-06-17 19:42:26,625 | server.py:232 | fit_round 7 received 6 results and 0 failures
# DEBUG:flwr:fit_round 7 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 19:42:26,688 | server.py:168 | evaluate_round 7: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 7: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 19:42:31,116 | server.py:182 | evaluate_round 7 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 7 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 19:42:31,120 | server.py:218 | fit_round 8: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 8: strategy sampled 6 clients (out of 6)
# [(6060, {'accuracy': 0.8836633563041687}), (5211, {'accuracy': 0.7179044485092163}), (6138, {'accuracy': 0.7008797526359558})]
# DEBUG flwr 2023-06-17 19:46:21,902 | server.py:232 | fit_round 8 received 6 results and 0 failures
# DEBUG:flwr:fit_round 8 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 19:46:21,988 | server.py:168 | evaluate_round 8: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 8: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 19:46:27,849 | server.py:182 | evaluate_round 8 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 8 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 19:46:27,853 | server.py:218 | fit_round 9: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 9: strategy sampled 6 clients (out of 6)
# [(6060, {'accuracy': 0.8412541151046753}), (5573, {'accuracy': 0.7247443199157715}), (5211, {'accuracy': 0.706582248210907})]
# DEBUG flwr 2023-06-17 19:50:17,027 | server.py:232 | fit_round 9 received 6 results and 0 failures
# DEBUG:flwr:fit_round 9 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 19:50:17,086 | server.py:168 | evaluate_round 9: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 9: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 19:50:20,426 | server.py:182 | evaluate_round 9 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 9 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 19:50:20,430 | server.py:218 | fit_round 10: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 10: strategy sampled 6 clients (out of 6)
# [(5573, {'accuracy': 0.6714516282081604}), (6138, {'accuracy': 0.5899315476417542}), (5098, {'accuracy': 0.4146724343299866})]
# DEBUG flwr 2023-06-17 19:54:11,190 | server.py:232 | fit_round 10 received 6 results and 0 failures
# DEBUG:flwr:fit_round 10 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 19:54:11,253 | server.py:168 | evaluate_round 10: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 10: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 19:54:14,919 | server.py:182 | evaluate_round 10 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 10 received 3 results and 0 failures
# INFO flwr 2023-06-17 19:54:14,926 | server.py:147 | FL finished in 2356.108645224
# INFO:flwr:FL finished in 2356.108645224
# INFO flwr 2023-06-17 19:54:14,931 | app.py:218 | app_fit: losses_distributed [(1, 1.373101212704682), (2, 1.1054602783929162), (3, 0.8414285615000259), (4, 0.4845165270398248), (5, 0.8389328008996336), (6, 1.5067260867666386), (7, 1.7023164120169112), (8, 1.2216282808187595), (9, 4.675667980693254), (10, 2.4958261006470503)]
# INFO:flwr:app_fit: losses_distributed [(1, 1.373101212704682), (2, 1.1054602783929162), (3, 0.8414285615000259), (4, 0.4845165270398248), (5, 0.8389328008996336), (6, 1.5067260867666386), (7, 1.7023164120169112), (8, 1.2216282808187595), (9, 4.675667980693254), (10, 2.4958261006470503)]
# INFO flwr 2023-06-17 19:54:14,934 | app.py:219 | app_fit: metrics_distributed_fit {}
# INFO:flwr:app_fit: metrics_distributed_fit {}
# INFO flwr 2023-06-17 19:54:14,937 | app.py:220 | app_fit: metrics_distributed {'accuracy': [(1, 0.8114118145974382), (2, 0.7854425232051904), (3, 0.717113832458933), (4, 0.8438679260395046), (5, 0.6924059130924121), (6, 0.6515474131986233), (7, 0.7696019267082708), (8, 0.7610425153082381), (9, 0.5638050945114782), (10, 0.6435203379848438)]}
# INFO:flwr:app_fit: metrics_distributed {'accuracy': [(1, 0.8114118145974382), (2, 0.7854425232051904), (3, 0.717113832458933), (4, 0.8438679260395046), (5, 0.6924059130924121), (6, 0.6515474131986233), (7, 0.7696019267082708), (8, 0.7610425153082381), (9, 0.5638050945114782), (10, 0.6435203379848438)]}
# INFO flwr 2023-06-17 19:54:14,939 | app.py:221 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2023-06-17 19:54:14,941 | app.py:222 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# [(5573, {'accuracy': 0.5903463363647461}), (6138, {'accuracy': 0.5500162839889526}), (6060, {'accuracy': 0.7871286869049072})]
# History (loss, distributed):
# 	round 1: 1.373101212704682
# 	round 2: 1.1054602783929162
# 	round 3: 0.8414285615000259
# 	round 4: 0.4845165270398248
# 	round 5: 0.8389328008996336
# 	round 6: 1.5067260867666386
# 	round 7: 1.7023164120169112
# 	round 8: 1.2216282808187595
# 	round 9: 4.675667980693254
# 	round 10: 2.4958261006470503
# History (metrics, distributed, evaluate):
# {'accuracy': [(1, 0.8114118145974382), (2, 0.7854425232051904), (3, 0.717113832458933), (4, 0.8438679260395046), (5, 0.6924059130924121), (6, 0.6515474131986233), (7, 0.7696019267082708), (8, 0.7610425153082381), (9, 0.5638050945114782), (10, 0.6435203379848438)]}
