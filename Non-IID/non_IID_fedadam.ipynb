# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q flwr["simulation"] tensorflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 MB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 92.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 18.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 94.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 9.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 57.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 36.9 MB/s eta 0:00:00
#   Building wheel for gpustat (pyproject.toml) ... done

# %%
import flwr as fl
import tensorflow as tf
import numpy as np
from typing import List, Tuple
from flwr.common import Metrics
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
client_0_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_X_train.npy")
client_0_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_y_train.npy")
client_0_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_X_test.npy")
client_0_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_y_test.npy")

client_1_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_X_train.npy")
client_1_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_y_train.npy")
client_1_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_X_test.npy")
client_1_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_y_test.npy")

client_2_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_X_train.npy")
client_2_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_y_train.npy")
client_2_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_X_test.npy")
client_2_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_y_test.npy")

client_3_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_X_train.npy")
client_3_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_y_train.npy")
client_3_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_X_test.npy")
client_3_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_y_test.npy")

client_4_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_X_train.npy")
client_4_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_y_train.npy")
client_4_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_X_test.npy")
client_4_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_y_test.npy")

client_5_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_X_train.npy")
client_5_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_y_train.npy")
client_5_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_X_test.npy")
client_5_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_y_test.npy")

# %%
x_train = [client_0_train_data, client_1_train_data, client_2_train_data, client_3_train_data, client_4_train_data, client_5_train_data]
y_train = [client_0_train_label, client_1_train_label, client_2_train_label, client_3_train_label, client_4_train_label, client_5_train_label]
x_test = [client_0_test_data, client_1_test_data, client_2_test_data, client_3_test_data, client_4_test_data, client_5_test_data]
y_test = [client_0_test_label, client_1_test_label, client_2_test_label, client_3_test_label, client_4_test_label, client_5_test_label]

# %%
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, model, x_train_cid, y_train_cid, x_test_cid, y_test_cid) -> None:
        self.model = model
        self.x_train_cid, self.y_train_cid = x_train_cid, y_train_cid
        self.x_test_cid, self.y_test_cid = x_test_cid, y_test_cid

    def get_parameters(self, config):
        return self.model.get_weights()

    def fit(self, parameters, config):
        self.model.set_weights(parameters)
        self.model.fit(self.x_train_cid, self.y_train_cid, epochs=5, batch_size=32, verbose=0)
        return self.model.get_weights(), len(self.x_train_cid), {}

    def evaluate(self, parameters, config):
        self.model.set_weights(parameters)
        loss, acc = self.model.evaluate(self.x_test_cid, self.y_test_cid, verbose=0)
        return loss, len(self.x_test_cid), {"accuracy": acc}

# %%
def client_fn(cid: str) -> fl.client.Client:

    model = Sequential([
      layers.Conv1D(16, 3, padding='same', activation='relu', input_shape=(180,1)),
      layers.MaxPool1D(),
      layers.Conv1D(32, 3, padding='same', activation='relu'),
      layers.MaxPool1D(),
      layers.Conv1D(64, 3, padding='same', activation='relu'),
      layers.MaxPool1D(),
      layers.Flatten(),
      layers.Dense(256, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(5 ,activation="softmax")
    ])
    model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=[tf.keras.metrics.CategoricalAccuracy()])

    x_train_cid = x_train[int(cid)]
    y_train_cid = y_train[int(cid)]

    x_test_cid = x_test[int(cid)]
    y_test_cid = y_test[int(cid)]


    return FlowerClient(model, x_train_cid, y_train_cid, x_test_cid, y_test_cid)

# %%
def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:

    print(metrics)
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]


    return {"accuracy": sum(accuracies) / sum(examples)}

# %%
#created for initial parameters
model = Sequential([
  layers.Conv1D(16, 3, padding='same', activation='relu', input_shape=(180,1)),
  layers.MaxPool1D(),
  layers.Conv1D(32, 3, padding='same', activation='relu'),
  layers.MaxPool1D(),
  layers.Conv1D(64, 3, padding='same', activation='relu'),
  layers.MaxPool1D(),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(64, activation='relu'),
  layers.Dense(5 ,activation="softmax")
])

# %%
strategy = fl.server.strategy.FedAdam(
    fraction_fit=1.0,
    fraction_evaluate=0.5,
    min_fit_clients=6,
    min_evaluate_clients=3,
    min_available_clients=6,
    initial_parameters=fl.common.ndarrays_to_parameters(model.get_weights()),
    evaluate_metrics_aggregation_fn=weighted_average,
)

client_resources = None


fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=6,
    config=fl.server.ServerConfig(num_rounds=10),
    strategy=strategy,
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-06-17 19:58:12,463 | app.py:146 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# 2023-06-17 19:58:18,019	INFO worker.py:1636 -- Started a local Ray instance.
# INFO flwr 2023-06-17 19:58:20,359 | app.py:180 | Flower VCE: Ray initialized with resources: {'node:172.28.0.12': 1.0, 'CPU': 2.0, 'object_store_memory': 3893590425.0, 'memory': 7787180852.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'node:172.28.0.12': 1.0, 'CPU': 2.0, 'object_store_memory': 3893590425.0, 'memory': 7787180852.0}
# INFO flwr 2023-06-17 19:58:20,368 | server.py:86 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2023-06-17 19:58:20,376 | server.py:269 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2023-06-17 19:58:20,382 | server.py:88 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2023-06-17 19:58:20,403 | server.py:101 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2023-06-17 19:58:20,416 | server.py:218 | fit_round 1: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 1: strategy sampled 6 clients (out of 6)
# (pid=2902) 2023-06-17 19:58:23.569945: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG flwr 2023-06-17 20:01:54,473 | server.py:232 | fit_round 1 received 6 results and 0 failures
# DEBUG:flwr:fit_round 1 received 6 results and 0 failures
# WARNING flwr 2023-06-17 20:01:54,542 | fedavg.py:243 | No fit_metrics_aggregation_fn provided
# WARNING:flwr:No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-06-17 20:01:54,581 | server.py:168 | evaluate_round 1: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 1: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 20:02:00,515 | server.py:182 | evaluate_round 1 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 1 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 20:02:00,524 | server.py:218 | fit_round 2: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 2: strategy sampled 6 clients (out of 6)
# [(5573, {'accuracy': 0.8386865258216858}), (6138, {'accuracy': 0.85418701171875}), (5211, {'accuracy': 0.6119746565818787})]
# DEBUG flwr 2023-06-17 20:05:25,422 | server.py:232 | fit_round 2 received 6 results and 0 failures
# DEBUG:flwr:fit_round 2 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 20:05:25,488 | server.py:168 | evaluate_round 2: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 2: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 20:05:31,385 | server.py:182 | evaluate_round 2 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 2 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 20:05:31,388 | server.py:218 | fit_round 3: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 3: strategy sampled 6 clients (out of 6)
# [(6060, {'accuracy': 0.8212871551513672}), (4762, {'accuracy': 0.6820663809776306}), (6138, {'accuracy': 0.6454871296882629})]
# DEBUG flwr 2023-06-17 20:08:55,710 | server.py:232 | fit_round 3 received 6 results and 0 failures
# DEBUG:flwr:fit_round 3 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 20:08:55,777 | server.py:168 | evaluate_round 3: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 3: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 20:09:01,341 | server.py:182 | evaluate_round 3 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 3 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 20:09:01,349 | server.py:218 | fit_round 4: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 4: strategy sampled 6 clients (out of 6)
# [(5211, {'accuracy': 0.6678180694580078}), (6060, {'accuracy': 0.8760725855827332}), (5573, {'accuracy': 0.671810507774353})]
# DEBUG flwr 2023-06-17 20:12:23,517 | server.py:232 | fit_round 4 received 6 results and 0 failures
# DEBUG:flwr:fit_round 4 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 20:12:23,577 | server.py:168 | evaluate_round 4: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 4: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 20:12:29,204 | server.py:182 | evaluate_round 4 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 4 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 20:12:29,208 | server.py:218 | fit_round 5: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 5: strategy sampled 6 clients (out of 6)
# [(6060, {'accuracy': 0.6900990009307861}), (4762, {'accuracy': 0.7704746127128601}), (5573, {'accuracy': 0.725462019443512})]
# DEBUG flwr 2023-06-17 20:15:51,395 | server.py:232 | fit_round 5 received 6 results and 0 failures
# DEBUG:flwr:fit_round 5 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 20:15:51,442 | server.py:168 | evaluate_round 5: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 5: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 20:15:56,627 | server.py:182 | evaluate_round 5 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 5 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 20:15:56,631 | server.py:218 | fit_round 6: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 6: strategy sampled 6 clients (out of 6)
# [(5211, {'accuracy': 0.17770101130008698}), (6138, {'accuracy': 0.2896709144115448}), (6060, {'accuracy': 0.32689768075942993})]
# DEBUG flwr 2023-06-17 20:19:21,151 | server.py:232 | fit_round 6 received 6 results and 0 failures
# DEBUG:flwr:fit_round 6 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 20:19:21,201 | server.py:168 | evaluate_round 6: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 6: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 20:19:26,394 | server.py:182 | evaluate_round 6 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 6 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 20:19:26,398 | server.py:218 | fit_round 7: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 7: strategy sampled 6 clients (out of 6)
# [(6138, {'accuracy': 0.7464972138404846}), (5573, {'accuracy': 0.8471200466156006}), (4762, {'accuracy': 0.768794596195221})]
# DEBUG flwr 2023-06-17 20:22:49,362 | server.py:232 | fit_round 7 received 6 results and 0 failures
# DEBUG:flwr:fit_round 7 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 20:22:49,411 | server.py:168 | evaluate_round 7: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 7: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 20:22:53,661 | server.py:182 | evaluate_round 7 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 7 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 20:22:53,666 | server.py:218 | fit_round 8: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 8: strategy sampled 6 clients (out of 6)
# [(5211, {'accuracy': 0.6163883805274963}), (5098, {'accuracy': 0.7754021286964417}), (6060, {'accuracy': 0.9128713011741638})]
# DEBUG flwr 2023-06-17 20:26:19,651 | server.py:232 | fit_round 8 received 6 results and 0 failures
# DEBUG:flwr:fit_round 8 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 20:26:19,700 | server.py:168 | evaluate_round 8: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 8: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 20:26:23,877 | server.py:182 | evaluate_round 8 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 8 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 20:26:23,888 | server.py:218 | fit_round 9: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 9: strategy sampled 6 clients (out of 6)
# [(5098, {'accuracy': 0.7424480319023132}), (4762, {'accuracy': 0.7734145522117615}), (5211, {'accuracy': 0.7259643077850342})]
# DEBUG flwr 2023-06-17 20:29:49,419 | server.py:232 | fit_round 9 received 6 results and 0 failures
# DEBUG:flwr:fit_round 9 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 20:29:49,476 | server.py:168 | evaluate_round 9: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 9: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 20:29:53,798 | server.py:182 | evaluate_round 9 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 9 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 20:29:53,802 | server.py:218 | fit_round 10: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 10: strategy sampled 6 clients (out of 6)
# [(5098, {'accuracy': 0.2926637828350067}), (6138, {'accuracy': 0.5389377474784851}), (6060, {'accuracy': 0.7107260823249817})]
# DEBUG flwr 2023-06-17 20:33:17,723 | server.py:232 | fit_round 10 received 6 results and 0 failures
# DEBUG:flwr:fit_round 10 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 20:33:17,775 | server.py:168 | evaluate_round 10: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 10: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 20:33:21,517 | server.py:182 | evaluate_round 10 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 10 received 3 results and 0 failures
# INFO flwr 2023-06-17 20:33:21,521 | server.py:147 | FL finished in 2101.1050722699997
# INFO:flwr:FL finished in 2101.1050722699997
# INFO flwr 2023-06-17 20:33:21,528 | app.py:218 | app_fit: losses_distributed [(1, 9.030860484541062), (2, 3.590230461561455), (3, 3.155535620483529), (4, 1.0767929983851603), (5, 3.5782995239611477), (6, 2.769795738513849), (7, 2.701911548374117), (8, 1.7861753608590218), (9, 3.8511187056222522), (10, 2.6026410144777152)]
# INFO:flwr:app_fit: losses_distributed [(1, 9.030860484541062), (2, 3.590230461561455), (3, 3.155535620483529), (4, 1.0767929983851603), (5, 3.5782995239611477), (6, 2.769795738513849), (7, 2.701911548374117), (8, 1.7861753608590218), (9, 3.8511187056222522), (10, 2.6026410144777152)]
# INFO flwr 2023-06-17 20:33:21,530 | app.py:219 | app_fit: metrics_distributed_fit {}
# INFO:flwr:app_fit: metrics_distributed_fit {}
# INFO flwr 2023-06-17 20:33:21,535 | app.py:220 | app_fit: metrics_distributed {'accuracy': [(1, 0.774494730042673), (2, 0.7185731290365165), (3, 0.7440631553314837), (4, 0.7254650738479961), (5, 0.2691136761413614), (6, 0.7869847499194609), (7, 0.7756735285074638), (8, 0.7465330881917732), (9, 0.5265379230923447), (10, 0.7421482452720254)]}
# INFO:flwr:app_fit: metrics_distributed {'accuracy': [(1, 0.774494730042673), (2, 0.7185731290365165), (3, 0.7440631553314837), (4, 0.7254650738479961), (5, 0.2691136761413614), (6, 0.7869847499194609), (7, 0.7756735285074638), (8, 0.7465330881917732), (9, 0.5265379230923447), (10, 0.7421482452720254)]}
# INFO flwr 2023-06-17 20:33:21,537 | app.py:221 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2023-06-17 20:33:21,543 | app.py:222 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# [(4762, {'accuracy': 0.7223855257034302}), (6060, {'accuracy': 0.9023102521896362}), (5098, {'accuracy': 0.5702236294746399})]
# History (loss, distributed):
# 	round 1: 9.030860484541062
# 	round 2: 3.590230461561455
# 	round 3: 3.155535620483529
# 	round 4: 1.0767929983851603
# 	round 5: 3.5782995239611477
# 	round 6: 2.769795738513849
# 	round 7: 2.701911548374117
# 	round 8: 1.7861753608590218
# 	round 9: 3.8511187056222522
# 	round 10: 2.6026410144777152
# History (metrics, distributed, evaluate):
# {'accuracy': [(1, 0.774494730042673), (2, 0.7185731290365165), (3, 0.7440631553314837), (4, 0.7254650738479961), (5, 0.2691136761413614), (6, 0.7869847499194609), (7, 0.7756735285074638), (8, 0.7465330881917732), (9, 0.5265379230923447), (10, 0.7421482452720254)]}
