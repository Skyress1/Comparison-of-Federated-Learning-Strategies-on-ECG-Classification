# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q flwr["simulation"] tensorflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 MB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 69.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 60.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 10.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 47.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 32.5 MB/s eta 0:00:00
#   Building wheel for gpustat (pyproject.toml) ... done

# %%
import flwr as fl
import tensorflow as tf
import numpy as np
from typing import List, Tuple
from flwr.common import Metrics
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
client_0_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_X_train.npy")
client_0_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_y_train.npy")
client_0_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_X_test.npy")
client_0_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_0_y_test.npy")

client_1_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_X_train.npy")
client_1_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_y_train.npy")
client_1_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_X_test.npy")
client_1_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_1_y_test.npy")

client_2_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_X_train.npy")
client_2_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_y_train.npy")
client_2_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_X_test.npy")
client_2_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_2_y_test.npy")

client_3_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_X_train.npy")
client_3_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_y_train.npy")
client_3_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_X_test.npy")
client_3_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_3_y_test.npy")

client_4_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_X_train.npy")
client_4_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_y_train.npy")
client_4_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_X_test.npy")
client_4_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_4_y_test.npy")

client_5_train_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_X_train.npy")
client_5_train_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_y_train.npy")
client_5_test_data = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_X_test.npy")
client_5_test_label = np.load("/content/drive/MyDrive/federated_learning_ecg/noniid/client_5_y_test.npy")

# %%
x_train = [client_0_train_data, client_1_train_data, client_2_train_data, client_3_train_data, client_4_train_data, client_5_train_data]
y_train = [client_0_train_label, client_1_train_label, client_2_train_label, client_3_train_label, client_4_train_label, client_5_train_label]
x_test = [client_0_test_data, client_1_test_data, client_2_test_data, client_3_test_data, client_4_test_data, client_5_test_data]
y_test = [client_0_test_label, client_1_test_label, client_2_test_label, client_3_test_label, client_4_test_label, client_5_test_label]

# %%
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, model, x_train_cid, y_train_cid, x_test_cid, y_test_cid) -> None:
        self.model = model
        self.x_train_cid, self.y_train_cid = x_train_cid, y_train_cid
        self.x_test_cid, self.y_test_cid = x_test_cid, y_test_cid

    def get_parameters(self, config):
        return self.model.get_weights()

    def fit(self, parameters, config):
        self.model.set_weights(parameters)
        self.model.fit(self.x_train_cid, self.y_train_cid, epochs=5, batch_size=32, verbose=0)
        return self.model.get_weights(), len(self.x_train_cid), {}

    def evaluate(self, parameters, config):
        self.model.set_weights(parameters)
        loss, acc = self.model.evaluate(self.x_test_cid, self.y_test_cid, verbose=0)
        return loss, len(self.x_test_cid), {"accuracy": acc}

# %%
def client_fn(cid: str) -> fl.client.Client:

    model = Sequential([
      layers.Conv1D(16, 3, padding='same', activation='relu', input_shape=(180,1)),
      layers.MaxPool1D(),
      layers.Conv1D(32, 3, padding='same', activation='relu'),
      layers.MaxPool1D(),
      layers.Conv1D(64, 3, padding='same', activation='relu'),
      layers.MaxPool1D(),
      layers.Flatten(),
      layers.Dense(256, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(5 ,activation="softmax")
    ])
    model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=[tf.keras.metrics.CategoricalAccuracy()])

    x_train_cid = x_train[int(cid)]
    y_train_cid = y_train[int(cid)]

    x_test_cid = x_test[int(cid)]
    y_test_cid = y_test[int(cid)]


    return FlowerClient(model, x_train_cid, y_train_cid, x_test_cid, y_test_cid)

# %%
def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:

    print(metrics)
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]


    return {"accuracy": sum(accuracies) / sum(examples)}

# %%
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,
    fraction_evaluate=0.5,
    min_fit_clients=6,
    min_evaluate_clients=3,
    min_available_clients=6,
    evaluate_metrics_aggregation_fn=weighted_average,
)

client_resources = None


fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=6,
    config=fl.server.ServerConfig(num_rounds=10),
    strategy=strategy,
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-06-17 17:16:05,330 | app.py:146 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# 2023-06-17 17:16:08,454	INFO worker.py:1636 -- Started a local Ray instance.
# INFO flwr 2023-06-17 17:16:11,674 | app.py:180 | Flower VCE: Ray initialized with resources: {'memory': 7803369063.0, 'object_store_memory': 3901684531.0, 'node:172.28.0.12': 1.0, 'CPU': 2.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'memory': 7803369063.0, 'object_store_memory': 3901684531.0, 'node:172.28.0.12': 1.0, 'CPU': 2.0}
# INFO flwr 2023-06-17 17:16:11,684 | server.py:86 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2023-06-17 17:16:11,693 | server.py:273 | Requesting initial parameters from one random client
# INFO:flwr:Requesting initial parameters from one random client
# (pid=1125) 2023-06-17 17:16:14.539173: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO flwr 2023-06-17 17:16:16,656 | server.py:277 | Received initial parameters from one random client
# INFO:flwr:Received initial parameters from one random client
# INFO flwr 2023-06-17 17:16:16,661 | server.py:88 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2023-06-17 17:16:16,665 | server.py:101 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2023-06-17 17:16:16,669 | server.py:218 | fit_round 1: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 1: strategy sampled 6 clients (out of 6)
# (pid=1126) 2023-06-17 17:16:19.650942: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG flwr 2023-06-17 17:19:26,597 | server.py:232 | fit_round 1 received 6 results and 0 failures
# DEBUG:flwr:fit_round 1 received 6 results and 0 failures
# WARNING flwr 2023-06-17 17:19:26,636 | fedavg.py:243 | No fit_metrics_aggregation_fn provided
# WARNING:flwr:No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-06-17 17:19:26,640 | server.py:168 | evaluate_round 1: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 1: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 17:19:30,307 | server.py:182 | evaluate_round 1 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 1 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 17:19:30,311 | server.py:218 | fit_round 2: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 2: strategy sampled 6 clients (out of 6)
# [(6060, {'accuracy': 0.8912541270256042}), (5098, {'accuracy': 0.9021185040473938}), (5211, {'accuracy': 0.6113989353179932})]
# DEBUG flwr 2023-06-17 17:22:36,907 | server.py:232 | fit_round 2 received 6 results and 0 failures
# DEBUG:flwr:fit_round 2 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 17:22:36,958 | server.py:168 | evaluate_round 2: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 2: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 17:22:41,027 | server.py:182 | evaluate_round 2 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 2 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 17:22:41,035 | server.py:218 | fit_round 3: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 3: strategy sampled 6 clients (out of 6)
# [(6060, {'accuracy': 0.9044554233551025}), (5573, {'accuracy': 0.8180513381958008}), (5098, {'accuracy': 0.5064731240272522})]
# DEBUG flwr 2023-06-17 17:25:46,417 | server.py:232 | fit_round 3 received 6 results and 0 failures
# DEBUG:flwr:fit_round 3 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 17:25:46,459 | server.py:168 | evaluate_round 3: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 3: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 17:25:49,627 | server.py:182 | evaluate_round 3 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 3 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 17:25:49,634 | server.py:218 | fit_round 4: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 4: strategy sampled 6 clients (out of 6)
# [(5211, {'accuracy': 0.620610237121582}), (6060, {'accuracy': 0.8617161512374878}), (6138, {'accuracy': 0.708862841129303})]
# DEBUG flwr 2023-06-17 17:28:55,664 | server.py:232 | fit_round 4 received 6 results and 0 failures
# DEBUG:flwr:fit_round 4 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 17:28:55,696 | server.py:168 | evaluate_round 4: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 4: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 17:29:00,359 | server.py:182 | evaluate_round 4 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 4 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 17:29:00,362 | server.py:218 | fit_round 5: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 5: strategy sampled 6 clients (out of 6)
# [(5211, {'accuracy': 0.6271349191665649}), (6138, {'accuracy': 0.713750422000885}), (5098, {'accuracy': 0.6057277321815491})]
# DEBUG flwr 2023-06-17 17:32:06,255 | server.py:232 | fit_round 5 received 6 results and 0 failures
# DEBUG:flwr:fit_round 5 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 17:32:06,287 | server.py:168 | evaluate_round 5: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 5: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 17:32:09,069 | server.py:182 | evaluate_round 5 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 5 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 17:32:09,074 | server.py:218 | fit_round 6: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 6: strategy sampled 6 clients (out of 6)
# [(4762, {'accuracy': 0.8261234760284424}), (6138, {'accuracy': 0.7427501082420349}), (5573, {'accuracy': 0.8742149472236633})]
# DEBUG flwr 2023-06-17 17:35:14,465 | server.py:232 | fit_round 6 received 6 results and 0 failures
# DEBUG:flwr:fit_round 6 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 17:35:14,496 | server.py:168 | evaluate_round 6: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 6: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 17:35:17,264 | server.py:182 | evaluate_round 6 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 6 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 17:35:17,271 | server.py:218 | fit_round 7: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 7: strategy sampled 6 clients (out of 6)
# [(6138, {'accuracy': 0.8095470666885376}), (5573, {'accuracy': 0.8844428658485413}), (4762, {'accuracy': 0.8748425245285034})]
# DEBUG flwr 2023-06-17 17:38:23,893 | server.py:232 | fit_round 7 received 6 results and 0 failures
# DEBUG:flwr:fit_round 7 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 17:38:23,936 | server.py:168 | evaluate_round 7: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 7: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 17:38:29,388 | server.py:182 | evaluate_round 7 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 7 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 17:38:29,392 | server.py:218 | fit_round 8: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 8: strategy sampled 6 clients (out of 6)
# [(6138, {'accuracy': 0.868686854839325}), (5573, {'accuracy': 0.8806746602058411}), (6060, {'accuracy': 0.8750824928283691})]
# DEBUG flwr 2023-06-17 17:41:34,601 | server.py:232 | fit_round 8 received 6 results and 0 failures
# DEBUG:flwr:fit_round 8 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 17:41:34,632 | server.py:168 | evaluate_round 8: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 8: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 17:41:37,496 | server.py:182 | evaluate_round 8 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 8 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 17:41:37,502 | server.py:218 | fit_round 9: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 9: strategy sampled 6 clients (out of 6)
# [(6060, {'accuracy': 0.9222772121429443}), (5098, {'accuracy': 0.5982738137245178}), (5211, {'accuracy': 0.8595279455184937})]
# DEBUG flwr 2023-06-17 17:44:45,004 | server.py:232 | fit_round 9 received 6 results and 0 failures
# DEBUG:flwr:fit_round 9 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 17:44:45,036 | server.py:168 | evaluate_round 9: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 9: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 17:44:47,926 | server.py:182 | evaluate_round 9 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 9 received 3 results and 0 failures
# DEBUG flwr 2023-06-17 17:44:47,930 | server.py:218 | fit_round 10: strategy sampled 6 clients (out of 6)
# DEBUG:flwr:fit_round 10: strategy sampled 6 clients (out of 6)
# [(5211, {'accuracy': 0.8675878047943115}), (6060, {'accuracy': 0.9244224429130554}), (4762, {'accuracy': 0.8590928316116333})]
# DEBUG flwr 2023-06-17 17:47:59,498 | server.py:232 | fit_round 10 received 6 results and 0 failures
# DEBUG:flwr:fit_round 10 received 6 results and 0 failures
# DEBUG flwr 2023-06-17 17:47:59,532 | server.py:168 | evaluate_round 10: strategy sampled 3 clients (out of 6)
# DEBUG:flwr:evaluate_round 10: strategy sampled 3 clients (out of 6)
# DEBUG flwr 2023-06-17 17:48:02,376 | server.py:182 | evaluate_round 10 received 3 results and 0 failures
# DEBUG:flwr:evaluate_round 10 received 3 results and 0 failures
# INFO flwr 2023-06-17 17:48:02,383 | server.py:147 | FL finished in 1905.7144122690001
# INFO:flwr:FL finished in 1905.7144122690001
# INFO flwr 2023-06-17 17:48:02,389 | app.py:218 | app_fit: losses_distributed [(1, 0.6617621285206484), (2, 0.657824465204401), (3, 0.7699842655553955), (4, 1.2220338495145737), (5, 0.6869848467378402), (6, 0.4456191267398713), (7, 0.4513326319032351), (8, 0.8692717487843066), (9, 0.4151447879497062), (10, 0.5118631857243173)]
# INFO:flwr:app_fit: losses_distributed [(1, 0.6617621285206484), (2, 0.657824465204401), (3, 0.7699842655553955), (4, 1.2220338495145737), (5, 0.6869848467378402), (6, 0.4456191267398713), (7, 0.4513326319032351), (8, 0.8692717487843066), (9, 0.4151447879497062), (10, 0.5118631857243173)]
# INFO flwr 2023-06-17 17:48:02,393 | app.py:219 | app_fit: metrics_distributed_fit {}
# INFO:flwr:app_fit: metrics_distributed_fit {}
# INFO flwr 2023-06-17 17:48:02,397 | app.py:220 | app_fit: metrics_distributed {'accuracy': [(1, 0.805547070398365), (2, 0.7544079827618224), (3, 0.7356539686938596), (4, 0.6528242313297221), (5, 0.8113276305539081), (6, 0.8537607046993807), (7, 0.8746271849007284), (8, 0.8013928726281816), (9, 0.886546505268563), (10, 0.8770715691588409)]}
# INFO:flwr:app_fit: metrics_distributed {'accuracy': [(1, 0.805547070398365), (2, 0.7544079827618224), (3, 0.7356539686938596), (4, 0.6528242313297221), (5, 0.8113276305539081), (6, 0.8537607046993807), (7, 0.8746271849007284), (8, 0.8013928726281816), (9, 0.886546505268563), (10, 0.8770715691588409)]}
# INFO flwr 2023-06-17 17:48:02,404 | app.py:221 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2023-06-17 17:48:02,408 | app.py:222 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# [(6138, {'accuracy': 0.8594004511833191}), (4762, {'accuracy': 0.891642153263092}), (5573, {'accuracy': 0.8840839862823486})]
# History (loss, distributed):
# 	round 1: 0.6617621285206484
# 	round 2: 0.657824465204401
# 	round 3: 0.7699842655553955
# 	round 4: 1.2220338495145737
# 	round 5: 0.6869848467378402
# 	round 6: 0.4456191267398713
# 	round 7: 0.4513326319032351
# 	round 8: 0.8692717487843066
# 	round 9: 0.4151447879497062
# 	round 10: 0.5118631857243173
# History (metrics, distributed, evaluate):
# {'accuracy': [(1, 0.805547070398365), (2, 0.7544079827618224), (3, 0.7356539686938596), (4, 0.6528242313297221), (5, 0.8113276305539081), (6, 0.8537607046993807), (7, 0.8746271849007284), (8, 0.8013928726281816), (9, 0.886546505268563), (10, 0.8770715691588409)]}
